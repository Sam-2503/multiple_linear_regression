# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Student_Performance.csv")
df['Extracurricular Activities'] = (df['Extracurricular Activities'] == "Yes")
print(df)
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        True            9
# 1                 4               82                       False            4
# 2                 8               51                        True            7
# 3                 5               52                        True            5
# 4                 7               75                       False            8
# ...             ...              ...                         ...          ...
# 9995              1               49                        True            4
# 9996              7               64                        True            8
# 9997              6               83                        True            8
# 9998              9               97                        True            7
# 9999              7               74                       False            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 6 columns]

# %%
X_train = df.iloc[:, :-1].to_numpy()
y_train = df.iloc[:, -1].to_numpy()
print(y_train)
# Out:
# [91. 65. 45. ... 74. 95. 64.]

# %%
linreg = LinearRegression()

# %%
linreg.fit(X_train, y_train)
predictions = linreg.predict(X_train)

# %%
# plotting the training data
fig, ax = plt.subplots(1, X_train.shape[1], figsize=(20, 5))
fig.suptitle("Scatter Plot of Training Dataset")
X_labels = ["Hours Studied", "Previous Scores", "Extracurricular Activities", "Sleep Hours", "Sample Question Papers Practiced"]

for i in range(len(ax)):
    ax[i].scatter(X_train[:, i], y_train, label = "training data")
    ax[i].scatter(X_train[:, i], predictions, label = "predicted data")
    ax[i].set_ylabel("Performance Index")
    ax[i].set_xlabel(X_labels[i])
    ax[i].legend()

plt.tight_layout()
plt.show()
